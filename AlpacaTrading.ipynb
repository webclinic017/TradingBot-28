# %% [raw]
# For more information:
# https://alpaca.markets/docs/trading/getting-started/

# %% [raw]
# pip install --ignore-installed alpaca-trade-api

# %%
import alpaca_trade_api as api

API_KEY = 'PKQA6MM20L2CQZKAOAHW'
API_SECRET = '4AJeSo8hcSqHa2TNwJv9IS8efb5PNDxHUju3UJjH'
BASE_URL = "https://paper-api.alpaca.markets"

alpaca = api.REST(API_KEY, API_SECRET, BASE_URL)

# %%
account = alpaca.get_account()

# %%
order = alpaca.submit_order("ETHUSD", qty=9)
print(order)
# Out:
# Order({   'asset_class': 'crypto',
#     'asset_id': '35f33a69-f5d6-4dc9-b158-4485e5e92e4b',
#     'canceled_at': None,
#     'client_order_id': 'da1affb8-3d3a-4788-9e76-7f7ddfd5d187',
#     'created_at': '2022-07-21T09:55:17.7726545Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'd8f14589-f210-48af-930a-2d22b7edbe0e',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '9',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'source': None,
#     'status': 'pending_new',
#     'stop_price': None,
#     'submitted_at': '2022-07-21T09:55:17.77046071Z',
#     'subtag': None,
#     'symbol': 'ETHUSD',
#     'time_in_force': 'day',
#     'trail_percent': None,
#     'trail_price': None,
# ...

# %%
positions = alpaca.list_positions()
for position in positions:
    print(position)
# Out:
# Position({   'asset_class': 'crypto',
#     'asset_id': '64bbff51-59d6-4b3c-9351-13ad85e3c752',
#     'asset_marginable': False,
#     'avg_entry_price': '22936',
#     'change_today': '-0.010594315245478',
#     'cost_basis': '22936',
#     'current_price': '22974',
#     'exchange': 'FTXU',
#     'lastday_price': '23220',
#     'market_value': '22974',
#     'qty': '1',
#     'qty_available': '1',
#     'side': 'long',
#     'symbol': 'BTCUSD',
#     'unrealized_intraday_pl': '38',
#     'unrealized_intraday_plpc': '0.0016567840948727',
#     'unrealized_pl': '38',
#     'unrealized_plpc': '0.0016567840948727'})
# Position({   'asset_class': 'crypto',
#     'asset_id': '35f33a69-f5d6-4dc9-b158-4485e5e92e4b',
#     'asset_marginable': False,
#     'avg_entry_price': '1509.76',
#     'change_today': '-0.0134684537430533',
#     'cost_basis': '15097.6',
#     'current_price': '1508.9',
#     'exchange': 'FTXU',
#     'lastday_price': '1529.5',
#     'market_value': '15089',
# ...

# %%
help(alpaca)
# Out:
# Help on REST in module alpaca_trade_api.rest object:
#
# class REST(builtins.object)
#  |  REST(key_id: str = None, secret_key: str = None, base_url: alpaca_trade_api.common.URL = None, api_version: str = None, oauth=None, raw_data: bool = False)
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |
#  |  __init__(self, key_id: str = None, secret_key: str = None, base_url: alpaca_trade_api.common.URL = None, api_version: str = None, oauth=None, raw_data: bool = False)
#  |      :param raw_data: should we return api response raw or wrap it with
#  |                       Entity objects.
#  |
#  |  add_to_watchlist(self, watchlist_id: str, symbol: str) -> alpaca_trade_api.entity.Watchlist
#  |      Add an asset to the watchlist
#  |
#  |  cancel_all_orders(self) -> None
#  |      Cancel all open orders
#  |
#  |  cancel_order(self, order_id: str) -> None
#  |      Cancel an order
#  |
#  |  close(self)
#  |
# ...

# %% [raw]
# from alpaca_trade_api.rest import REST, TimeFrame
# from alpaca_trade_api.stream import Stream
#
# rest_api = REST(API_KEY, SECRET_KEY, 'https://paper-api.alpaca.markets')
