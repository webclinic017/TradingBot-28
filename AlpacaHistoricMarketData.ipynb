# %%
import alpaca_trade_api as api

API_KEY = 'PKQA6MM20L2CQZKAOAHW'
API_SECRET = '4AJeSo8hcSqHa2TNwJv9IS8efb5PNDxHUju3UJjH'
BASE_URL = "https://paper-api.alpaca.markets"

alpaca = api.REST(API_KEY, API_SECRET, BASE_URL)
# Out:
# C:\Users\jordi\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jordi\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\jordi\anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def get_crypto_historic_data(symbol, timeframe = "1Min", start = "2022-01-25", end = "2022-01-31", exchange = "CBSE"):
    return alpaca.get_crypto_bars(symbol, timeframe, start, end, exchanges = exchange).df    

def get_stock_historic_data(symbol, timeframe = "1Min", start = "2022-01-25", end = "2022-01-31"):
    return alpaca.get_bars(symbol, timeframe, start, end).df

# %%
get_crypto_historic_data("BTCUSD", timeframe = "15min")

# %%
get_stock_historic_data("TSLA", start = "2022-06-30", end = "2022-07-24")
# Out:
#                              open    high     low   close  volume  \
# timestamp
# 2022-06-30 08:00:00+00:00  669.90  671.95  669.36  670.00    5239
# 2022-06-30 08:01:00+00:00  671.96  672.10  671.55  671.55    3054
# 2022-06-30 08:02:00+00:00  672.00  672.54  672.00  672.54    2604
# 2022-06-30 08:04:00+00:00  673.03  673.75  673.03  673.75    2841
# 2022-06-30 08:05:00+00:00  673.93  674.45  673.60  674.45    3881
# ...                           ...     ...     ...     ...     ...
# 2022-07-22 23:54:00+00:00  814.30  814.30  814.30  814.30    1226
# 2022-07-22 23:55:00+00:00  814.75  814.75  814.75  814.75     490
# 2022-07-22 23:56:00+00:00  814.67  814.67  814.11  814.11    1316
# 2022-07-22 23:58:00+00:00  814.40  814.40  814.40  814.40    1788
# 2022-07-22 23:59:00+00:00  814.64  815.00  814.41  815.00    2208
#
#                            trade_count        vwap
# timestamp
# 2022-06-30 08:00:00+00:00          302  670.097284
# 2022-06-30 08:01:00+00:00          169  671.754856
# 2022-06-30 08:02:00+00:00          181  671.887700
# 2022-06-30 08:04:00+00:00          133  673.359219
# 2022-06-30 08:05:00+00:00           86  674.251417
# ...                                ...         ...
# 2022-07-22 23:54:00+00:00           37  814.356884
# 2022-07-22 23:55:00+00:00           35  814.584306
# 2022-07-22 23:56:00+00:00           48  814.427831
# 2022-07-22 23:58:00+00:00           69  814.434673
# 2022-07-22 23:59:00+00:00          125  814.664914
#
# [12197 rows x 7 columns]

# %% [raw]
# ## Here i am attempting to get live data, but unable to get it to function ##

# %%
from alpaca_trade_api.stream import Stream
import nest_asyncio
nest_asyncio.apply()

# %%
data_feed = "iex" # Change to "sip" if using paid subscription

# Instantiate Stream class
stream = Stream(API_KEY,
                API_SECRET,
                base_url=BASE_URL,
                data_feed=data_feed)

# %%
async def bar_callback(b):
    print("test")
    print(b)

# Subscribing to bar event
symbol = "BTCUSD"
stream.subscribe_crypto_bars(bar_callback, symbol)

# %%
stream.run()
# Out:
# test
# Bar({   'close': 22920.78,
#     'exchange': 'CBSE',
#     'high': 22983.26,
#     'low': 22912.87,
#     'open': 22979.99,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511600000000000,
#     'trade_count': 620,
#     'volume': 43.52500122,
#     'vwap': 22945.7659467448})
# test
# Bar({   'close': 22945.0,
#     'exchange': 'ERSX',
#     'high': 22945.0,
#     'low': 22945.0,
#     'open': 22945.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511600000000000,
#     'trade_count': 1,
#     'volume': 0.2,
#     'vwap': 22945.0})
# test
# Bar({   'close': 22951.0,
#     'exchange': 'FTXU',
#     'high': 22973.0,
#     'low': 22951.0,
#     'open': 22973.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511600000000000,
#     'trade_count': 9,
#     'volume': 2.9144,
#     'vwap': 22967.1908797694})
# test
# Bar({   'close': 22920.98,
#     'exchange': 'CBSE',
#     'high': 22934.52,
#     'low': 22893.98,
#     'open': 22922.47,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511660000000000,
#     'trade_count': 644,
#     'volume': 32.59662522,
#     'vwap': 22908.3844465873})
# test
# Bar({   'close': 22898.0,
#     'exchange': 'FTXU',
#     'high': 22914.0,
#     'low': 22898.0,
#     'open': 22914.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511660000000000,
#     'trade_count': 8,
#     'volume': 0.9373,
#     'vwap': 22902.85660941})
# test
# Bar({   'close': 22911.56,
#     'exchange': 'CBSE',
#     'high': 22944.14,
#     'low': 22893.29,
#     'open': 22919.68,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511720000000000,
#     'trade_count': 385,
#     'volume': 22.87578127,
#     'vwap': 22913.1025676318})
# test
# Bar({   'close': 22900.0,
#     'exchange': 'FTXU',
#     'high': 22935.0,
#     'low': 22900.0,
#     'open': 22935.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511720000000000,
#     'trade_count': 3,
#     'volume': 0.7189,
#     'vwap': 22918.2591459174})
# test
# Bar({   'close': 22953.52,
#     'exchange': 'CBSE',
#     'high': 22960.89,
#     'low': 22904.7,
#     'open': 22912.48,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511780000000000,
#     'trade_count': 374,
#     'volume': 19.26479124,
#     'vwap': 22932.2019778183})
# test
# Bar({   'close': 22939.0,
#     'exchange': 'FTXU',
#     'high': 22939.0,
#     'low': 22920.0,
#     'open': 22921.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511780000000000,
#     'trade_count': 30,
#     'volume': 9.804,
#     'vwap': 22924.1261321909})
# test
# Bar({   'close': 22974.57,
#     'exchange': 'CBSE',
#     'high': 22974.57,
#     'low': 22946.63,
#     'open': 22956.97,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511840000000000,
#     'trade_count': 373,
#     'volume': 20.30009296,
#     'vwap': 22958.3373620479})
# test
# Bar({   'close': 22952.0,
#     'exchange': 'FTXU',
#     'high': 22953.0,
#     'low': 22944.0,
#     'open': 22944.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511840000000000,
#     'trade_count': 6,
#     'volume': 0.7708,
#     'vwap': 22952.1921380384})
# test
# Bar({   'close': 22950.15,
#     'exchange': 'CBSE',
#     'high': 22974.56,
#     'low': 22940.03,
#     'open': 22969.28,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511900000000000,
#     'trade_count': 450,
#     'volume': 42.50373968,
#     'vwap': 22953.3289099126})
# test
# Bar({   'close': 22954.0,
#     'exchange': 'FTXU',
#     'high': 22964.0,
#     'low': 22944.0,
#     'open': 22964.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511900000000000,
#     'trade_count': 9,
#     'volume': 1.6676,
#     'vwap': 22954.5973854641})
# test
# Bar({   'close': 22981.8,
#     'exchange': 'CBSE',
#     'high': 22988.41,
#     'low': 22950.13,
#     'open': 22950.14,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658511960000000000,
#     'trade_count': 360,
#     'volume': 15.15301829,
#     'vwap': 22967.2748771344})
# test
# Bar({   'close': 22994.62,
#     'exchange': 'CBSE',
#     'high': 23000.0,
#     'low': 22960.88,
#     'open': 22983.66,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512020000000000,
#     'trade_count': 439,
#     'volume': 21.82908203,
#     'vwap': 22979.1096861826})
# test
# Bar({   'close': 22986.0,
#     'exchange': 'FTXU',
#     'high': 22986.0,
#     'low': 22965.0,
#     'open': 22976.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512020000000000,
#     'trade_count': 16,
#     'volume': 2.1331,
#     'vwap': 22976.3722282125})
# test
# Bar({   'close': 23017.68,
#     'exchange': 'CBSE',
#     'high': 23031.27,
#     'low': 22998.27,
#     'open': 22998.27,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512080000000000,
#     'trade_count': 492,
#     'volume': 16.88589058,
#     'vwap': 23017.5037345387})
# test
# Bar({   'close': 23014.0,
#     'exchange': 'FTXU',
#     'high': 23025.0,
#     'low': 22991.0,
#     'open': 22991.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512080000000000,
#     'trade_count': 12,
#     'volume': 1.6709,
#     'vwap': 23000.8585193608})
# test
# Bar({   'close': 23002.72,
#     'exchange': 'CBSE',
#     'high': 23026.53,
#     'low': 22989.39,
#     'open': 23016.32,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512140000000000,
#     'trade_count': 425,
#     'volume': 17.85395262,
#     'vwap': 23003.8825826544})
# test
# Bar({   'close': 23008.0,
#     'exchange': 'FTXU',
#     'high': 23019.0,
#     'low': 22989.0,
#     'open': 23008.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512140000000000,
#     'trade_count': 12,
#     'volume': 1.4675,
#     'vwap': 23003.6016354344})
# test
# Bar({   'close': 22964.93,
#     'exchange': 'CBSE',
#     'high': 23004.14,
#     'low': 22943.36,
#     'open': 22998.22,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512200000000000,
#     'trade_count': 499,
#     'volume': 23.86582097,
#     'vwap': 22965.4948585215})
# test
# Bar({   'close': 22952.0,
#     'exchange': 'FTXU',
#     'high': 22993.0,
#     'low': 22952.0,
#     'open': 22993.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512200000000000,
#     'trade_count': 22,
#     'volume': 3.4934,
#     'vwap': 22966.7348142211})
# test
# Bar({   'close': 22956.56,
#     'exchange': 'CBSE',
#     'high': 22965.06,
#     'low': 22942.22,
#     'open': 22962.35,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512260000000000,
#     'trade_count': 409,
#     'volume': 21.67151824,
#     'vwap': 22955.3957319155})
# test
# Bar({   'close': 22951.0,
#     'exchange': 'FTXU',
#     'high': 22957.0,
#     'low': 22942.0,
#     'open': 22942.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512260000000000,
#     'trade_count': 6,
#     'volume': 3.7476,
#     'vwap': 22950.6526310172})
# test
# Bar({   'close': 22925.7,
#     'exchange': 'CBSE',
#     'high': 22958.93,
#     'low': 22916.27,
#     'open': 22957.55,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512320000000000,
#     'trade_count': 386,
#     'volume': 13.26282435,
#     'vwap': 22942.4300487477})
# test
# Bar({   'close': 22940.0,
#     'exchange': 'FTXU',
#     'high': 22948.0,
#     'low': 22940.0,
#     'open': 22948.0,
#     'symbol': 'BTCUSD',
#     'timestamp': 1658512320000000000,
#     'trade_count': 3,
#     'volume': 0.7,
#     'vwap': 22945.1428571429})
# keyboard interrupt, bye
